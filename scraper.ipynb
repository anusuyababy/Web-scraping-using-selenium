# %%
#importing all necessary libraries
from selenium import webdriver
from selenium.common import exceptions
import pandas as pd

# %%
browser = webdriver.Chrome('chromedriver.exe')

# %%
#preprocessing and scraping the data from the website through for loop
element_list = []
for page in range(1, 25, 1):
    # giving url of the walmart
    browser.get('https://www.walmart.com/reviews/product/14898365?sort=submission-desc&page=' + str(page))
    
    date = browser.find_elements_by_xpath('//span[@class="review-date-submissionTime"]')
    reviewer = browser.find_elements_by_xpath('//span[@class="review-footer-userNickname"]')
    title = browser.find_elements_by_xpath('//h3[@class="review-title font-bold"]')
    review = browser.find_elements_by_xpath('//div[@class="review-text"]')
    rating = browser.find_elements_by_xpath('//span[@class="visuallyhidden seo-avg-rating"]')
    
    
    for i in range(len(title)):
        element_list.append([date[i].text, reviewer[i].text, title[i].text, review[i].text, rating[i].text])

# %%
print(element_list)
# Out:
# [['August 1, 2021', 'Ro', 'Protecting those you love.', 'Love these, very easy to use', '4.8'], ['August 1, 2021', 'Maryellen', 'Always the best', 'Very confident in using these wipes on surfaces. With viruses you can never be to safe in protecting those you love.', ''], ['July 31, 2021', 'Miriam', 'Very nice deal reasonably priced', 'They are early in more days. Thank you.', ''], ['July 31, 2021', 'Susan', 'Hands Down The Best Wipe Ever!', "Why wouldn't anyone like this item? Especially now.", '5.0'], ['July 30, 2021', 'adrienne', "I'll need a refund. It's got to be our hot temps?", 'Such a good deal love being stocked up', '1.0'], ['July 30, 2021', 'Ghaziani', 'The real deal', 'These are very good for class rooms.', '5.0'], ['July 30, 2021', 'Jessica', 'Excellent', 'I like these Clorox wipes for cleaning the bathroom. And they are requested on daughters school supply list.', '5.0'], ['July 28, 2021', 'Alicia', 'Highly recommend', 'Clorox products are always the best choice. No strong scent. No irritants. Highly recommend', '5.0'], ['July 28, 2021', 'Fiesta', 'This is a must', 'Nothing like Clorox products', '5.0'], ['July 27, 2021', 'June', 'Great for cleaning.', "all the liquid was drained out of all three containers and the paper was peeling off the sides of each of them by the time and took the outer plastic off. They must have tipped inside of the box or got too hot inside the truck or something. I'm not sure.", '5.0'], ['July 27, 2021', 'Nene', 'Super Clorox', 'The real deal. Its effective', '5.0'], ['July 26, 2021', 'kathleen', 'clorox the wonder product for many uses', 'Great price, product and service', '5.0'], ['July 23, 2021', 'Linda', 'Love this product! Love', 'This a good buy did feel like going out that week in because weather reason Im the house have everything at hand an a good buy', '4.8'], ['July 23, 2021', 'Maggy74', 'Finally in stock', 'Ive used these before and they work for me.great', ''], ['July 22, 2021', 'Me', 'When Covud came along', 'goid deal though inflation has upped everything, speedy shipment.', ''], ['July 22, 2021', 'roseyg9493', 'Need to clean and', 'Love this product! Love the scent, the packaging, the ease of use. My husband uses them all the time. They have a nice texture and wipe away the mess all at once! Definitely recommend!', '5.0'], ['July 22, 2021', 'Ester', 'I love the scent', 'Love anything Clorox use products all the time for years. Since Covid shortage', '1.0'], ['July 21, 2021', 'debiann301', 'This product this amazing', 'When Covud came along I used whatever wipes I could find. When Clorox hit the shelves again I stocked up. These wipes are tough; you can scrub pretty hard with them. And, being Clorox, you can rest assured that you are disinfecting your house.', '5.0'], ['July 20, 2021', 'mike', "These Clorox wipes don't", 'Easy to use and effective.', '5.0'], ['July 20, 2021', 'neenees', 'Satisfied', 'Need to clean and disinfect all at once. Clorox is key. And easy clean. It pretty much gives you, your surface back immediately after', '5.0'], ['July 20, 2021', 'mystiel', 'Leaked all in the box', "I love the scent and the strong durable quality of these wipes. The have a refreshing sent that isn't overbearing in the least. Much more pleasant than the usual bleach smell that fills my home ⭐⭐⭐⭐⭐Clorox Disinfecting Wipes Bleach Free Cleaning Wipes - Crisp Lemon - 75ct", '5.0'], ['July 14, 2021', 'Meechie', 'Excellent for cleaning', 'Cleans very well, especially for spot cleaning, or if youre in a hurry', '4.8'], ['July 14, 2021', 'maribelg42', 'The Clorox Disinfecting Wipes', 'The Clorox Disinfecting Wipes help to maintain the bathroom and the kitchen very clean .I used it every day for the lid of the toilet and I like very much.', ''], ['July 13, 2021', 'Debra', 'We use these all', 'Containers of wipes were dented and must have leaked cleaner liquid because Clorox labels were peeled off containers.', ''], ['July 13, 2021', 'Pilu', 'Disinfecting wipes', 'It cleans everything in ...

# %%
# creating dataframe for that data
df = pd.DataFrame(element_list, columns=['Date', 'Reviewer Name', 'Title', 'Review', 'Rating'])
df.head()
# Out:
#              Date Reviewer Name  \
# 0  August 1, 2021            Ro
# 1  August 1, 2021     Maryellen
# 2   July 31, 2021        Miriam
# 3   July 31, 2021         Susan
# 4   July 30, 2021      adrienne
#
#                                                Title  \
# 0                         Protecting those you love.
# 1                                    Always the best
# 2                   Very nice deal reasonably priced
# 3                     Hands Down The Best Wipe Ever!
# 4  I'll need a refund. It's got to be our hot temps?
#
#                                               Review Rating
# 0                       Love these, very easy to use    4.8
# 1  Very confident in using these wipes on surface...
# 2            They are early in more days. Thank you.
# 3  Why wouldn't anyone like this item? Especially...    5.0
# 4             Such a good deal love being stocked up    1.0

# %%
df.shape
# Out:
# (350, 5)

# %%
df.tail(10)
# Out:
#                   Date  Reviewer Name  \
# 340  December 16, 2020       sindhum6
# 341  December 16, 2020          Janet
# 342  December 15, 2020        trangyc
# 343  December 13, 2020     yeraldina4
# 344   December 6, 2020          Tyler
# 345   December 4, 2020  doedramontana
# 346   December 2, 2020  Octoberbaby79
# 347   December 1, 2020  christinaa110
# 348   December 1, 2020      higgy2132
# 349  November 27, 2020           day1
#
#                                               Title  \
# 340                        Love this products. Been
# 341                             I love these wipes!
# 342                              The fresh scent is
# 343                              I trully feel they
# 344                                     Kills germs
# 345                                  Great Product.
# 346  whatch out how they arrive. Ours were useless.
# 347       Fast shipping and very reasonably priced!
# 348   Official covid 19 killer from CDC list of US.
# 349                                    great price!
#
#                                                 Review Rating
# 340  Clorox disinfecting wipes are great especially...    1.0
# 341             I was so glad to get the CLOROX WIPES.    5.0
# 342  Love this products. Been using for years. Leav...    5.0
# 343  I trully feel they disinfect and clean very ni...    4.8
# 344                        Good as always! Kills germs
# 345  These are great cleaning wipes! They truly do ...
# 346  I have been purchasing this product for months...    5.0
# 347  I love these wipes. I wipe everything down wit...    1.0
# 348  It definitely cleans and disinfect, but the bl...    5.0
# 349  Good size, good price, good quality. No proble...    5.0

# %%
df.to_csv('output.csv', index=False)

# %%
browser.close()
